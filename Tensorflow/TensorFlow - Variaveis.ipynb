# %%
import tensorflow as tf
import numpy
#!pip install tensorflow==2.3.0
#%tensorflow_version 1.x

# %%
tf.__version__
# Out:
# '2.8.2'

# %%
tf.constant('caio')
# Out:
# <tf.Tensor: shape=(), dtype=string, numpy=b'caio'>

# %%
# necessário decodificar para utf-8
tf.constant('cáio')
# Out:
# <tf.Tensor: shape=(), dtype=string, numpy=b'c\xc3\xa1io'>

# %%
tf.constant(1)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=1>

# %%
tf.constant(3.2)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=3.2>

# %%
tf.constant([[1,2,3], [3,2,1]])
# Out:
# <tf.Tensor: shape=(2, 3), dtype=int32, numpy=
# array([[1, 2, 3],
#        [3, 2, 1]], dtype=int32)>

# %%
# atribuir o valor para um numero atribui para os restante (nesse caso sendo float)
tf.constant([[1.,2,3], [3,2,1]])
# Out:
# <tf.Tensor: shape=(2, 3), dtype=float32, numpy=
# array([[1., 2., 3.],
#        [3., 2., 1.]], dtype=float32)>

# %%
x = tf.constant([[1.,2,3], [3,2,1]])
x
# Out:
# <tf.Tensor: shape=(2, 3), dtype=float32, numpy=
# array([[1., 2., 3.],
#        [3., 2., 1.]], dtype=float32)>

# %%
x.numpy()
# Out:
# array([[1., 2., 3.],
#        [3., 2., 1.]], dtype=float32)

# %%
x = tf.Variable(2)
x
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=2>

# %%
x = tf.Variable('letícia')

# %%
x.numpy().decode('UTF-8')
# Out:
# 'letícia'

# %%
x = tf.Variable([[1,2], [1,2]])
x
# Out:
# <tf.Variable 'Variable:0' shape=(2, 2) dtype=int32, numpy=
# array([[1, 2],
#        [1, 2]], dtype=int32)>

# %%
x = tf.Variable(2)

# %%
## alterando o valor da variavel
x.assign(3)
# Out:
# <tf.Variable 'UnreadVariable' shape=() dtype=int32, numpy=3>

# %%
x.numpy()
# Out:
# 3

# %%
x = tf.Variable([[2,5], [10,9]])

# %%
## alterando valor da matriz da linha 0, coluna 3
x[0,1].assign(3)
# Out:
# <tf.Variable 'UnreadVariable' shape=(2, 2) dtype=int32, numpy=
# array([[ 2,  3],
#        [10,  9]], dtype=int32)>

# %%
x.numpy()
# Out:
# array([[ 2,  3],
#        [10,  9]], dtype=int32)
