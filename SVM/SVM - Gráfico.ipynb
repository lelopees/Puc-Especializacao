# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

from sklearn.datasets     import make_circles
from mpl_toolkits.mplot3d import Axes3D

# %%
# caracteristicas e rotulos
caracteristicas, c = make_circles(n_samples=500, noise=0.09)

# %%
#define as cores dos pontos no gráfico
rgb = np.array(['r','g'])
rgb
# Out:
# array(['r', 'g'], dtype='<U1')

# %%
# cria e exibe o gráfico do tipo Scatter plot
plt.scatter(caracteristicas[:,0], caracteristicas[:,1], color=rgb[c])
plt.show()

# %%
#gráfico com visualização 3D
fig = plt.figure(figsize=(18,5))
# adiciona a visualizaçã em 3 dimensões
ax = fig.add_subplot(111,projection='3d')
z = caracteristicas[:,0]**2+caracteristicas[:,1]**2
# cria o gráfico e exibe
ax.scatter(caracteristicas[:,0], caracteristicas[:,1],z,color=rgb[c])
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.show()
